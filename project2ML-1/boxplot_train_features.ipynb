# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

data=pd.read_csv("data_train.csv")
headers=list(data.columns.values)
headers=headers[:len(headers)-1]

for h in headers[1:]:
    if(is_numeric_dtype(data[h])):
#         bplot=sns.boxplot( x=data['class'],y=data[h],linewidth = 2 ,width=0.7)
#         plt.show()
#         bplot=sns.swarmplot(y=data[h], x=data['class'],data=data, color='yellow',alpha=0.75)
        
        
        # make boxplot with Seaborn
        bplot=sns.boxplot(y=data[h], x=data['class'], data=data, width=0.5,palette="colorblind")
 

        bplot=sns.stripplot(y=data[h], x=data['class'], data=data, jitter=True, marker='o', alpha=0.5,color='black')
        plt.show()
